# %%
import sqlite3 as lite
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import unicodedata
import re
# import pickle
import time
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Parameters - Flow Control
SIC_list = ['6029', '6022', '6035', '6036', '6099', '4512', '4513', '4522', '4581', '6163', '6172', '6199', '6200', '6211', '6221', '6282', '0100', '0200', '0700', '0800', '0900']
form_type = '10-K'
filter_filings_from='20170101'
filter_filings_before=None

# Store CIK Codes & Accession Numbers in a Dictionary - Insert Scraped Data into DataBase
CIK_codes_dict = {}

for SIC in SIC_list:
    CIK_codes_dict[SIC] = {}
    endpoint = r'https://www.sec.gov/cgi-bin/browse-edgar'
    params_dict= {'SIC':SIC,
                'myowner':'exclude',
                'action':'getcompany',
                'output':'atom'}

    user_agent = {'User-agent' : '<evanmcgarry7@gmail.com>', 'Host': 'www.sec.gov'}

    response = requests.get(url=endpoint, headers=user_agent, params=params_dict)
    
    soup = BeautifulSoup(response.content, 'xml')
    entries = soup.find_all('entry')

    for entry in entries:
        CIK = entry.find('cik').text
        CIK_codes_dict[SIC][CIK] = {}
    links = soup.find_all('link',{'rel':'next'})

    while soup.find_all('link',{'rel':'next'}) != []:
        next_page_link = links[0]['href']
        time.sleep(0.5)
        response = requests.get(url=next_page_link, headers=user_agent)
        soup = BeautifulSoup(response.content, 'xml')
        entries = soup.find_all('entry')

        for entry in entries:
            CIK = entry.find('cik').text
            CIK_codes_dict[SIC][CIK] = {}
        links = soup.find_all('link',{'rel':'next'})

for SIC, CIK_dict in CIK_codes_dict.items():
    for CIK in CIK_dict.keys():            
        endpoint = r'https://www.sec.gov/cgi-bin/browse-edgar'
        params_dict = {'action': 'getcompany',
            'CIK':str(CIK),
            'type':form_type,
            'datea':filter_filings_from,
            'dateb':filter_filings_before,
            'owner':'include',
            'output':'atom'}

        response = requests.get(url=endpoint, headers=user_agent, params=params_dict)
        soup = BeautifulSoup(response.content, 'xml')
        entries = soup.find_all('entry')
        conformed_name = soup.find('conformed-name').text
        print("Completed: ", conformed_name)
        CIK_dict[CIK] = {}
        for entry in entries:
            if entry.find('filing-type').text == '10-K':
                accession_no = entry.find('accession-number').text
                CIK_dict[CIK][accession_no] = {}
                CIK_dict[CIK][accession_no]['company_name'] = conformed_name
                CIK_dict[CIK][accession_no]['cik'] = CIK
                CIK_dict[CIK][accession_no]['filing_date'] = entry.find('filing-date').text
                CIK_dict[CIK][accession_no]['filing_type'] = entry.find('filing-type').text
                CIK_dict[CIK][accession_no]['filing_href'] = entry.find('filing-href').text

                time.sleep(.5)
                response = requests.get(url=CIK_dict[CIK][accession_no]['filing_href'], headers=user_agent)
                soup = BeautifulSoup(response.content, 'xml')
                a = soup.select("a[href*=Archives]")
                link = a[0]['href']
                CIK_dict[CIK][accession_no]['direct_link_to_doc_filed'] = 'https://www.sec.gov' + link[8:] if '/ix?doc=' in link else 'https://www.sec.gov' + link

# Create SQLite Database
con = lite.connect('SEC_Filings.db')
with con:
    cur=con.cursor()
    cur.execute("DROP TABLE IF EXISTS Reports_Data")
    cur.execute("CREATE TABLE Reports_Data(SIC TEXT, CIK TEXT, Company TEXT, Filing_Date TEXT, Filing_Link TEXT, Accession_No TEXT PRIMARY KEY NOT NULL UNIQUE)");
    for SIC, CIK_dict in CIK_codes_dict.items():
        for CIK in CIK_dict.keys():
            if CIK_dict[CIK]:
                for accession_no in CIK_dict[CIK].keys():
                    rowi = (SIC, CIK, CIK_dict[CIK][accession_no]['company_name'], CIK_dict[CIK][accession_no]['filing_date'], CIK_dict[CIK][accession_no]['direct_link_to_doc_filed'], accession_no)
                    cur.execute("INSERT OR IGNORE INTO Reports_Data VALUES(?,?,?,?,?,?)", rowi)
# Out:
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6029&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6022&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6035&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6036&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6099&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=4512&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=4513&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=4522&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=4581&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6163&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6172&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6199&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6200&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6211&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6221&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=6282&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=0100&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=0200&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=0700&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=0800&myowner=exclude&action=getcompany&output=atom
# https://www.sec.gov/cgi-bin/browse-edgar?SIC=0900&myowner=exclude&action=getcompany&output=atom
# Completed:  ABBEY NATIONAL PLC/ENG
# Completed:  ABBEY NATIONAL TREASURY SERVICES PLC/ENG
# Completed:  ALLIED IRISH BANKS PLC
# Completed:  AREA BANCSHARES CORP
# Completed:  AUSTRALIA & NEW ZEALAND BANKING GROUP LTD
# Completed:  Banco BBVA Argentina S.A.
# Completed:  BANCO BILBAO VIZCAYA ARGENTARIA CHILE
# Completed:  BANCO BILBAO VIZCAYA ARGENTARIA, S.A.
# Completed:  BANCO BILBAO VIZCAYA INTERNATIONAL GIBRALTAR LIMITED
# Completed:  BANCO CENTRAL HISPANOAMERICANO SA
# Completed:  BANCO COMERCIAL PORTUGUES SA
# Completed:  BANCO DO BRASIL S.A.
# Completed:  BANCO ESPIRITO SANTO E COMERCIAL DE LISBOA SA
# Completed:  BANCO ESPIRITO SANTO S A
# Completed:  BANCO RIO DE LA PLATA
# Completed:  Banco Santander (Brasil) S.A.
# Completed:  BANCO SANTANDER CHILE
# Completed:  Banco Santander Mexico S.A., Institucion de Banca Multiple, Grupo Financiero Santander Mexico
# Completed:  Banco Santander Rio S.A.
# Completed:  Banco Santander, S.A.
# Completed:  BANCO TOTTA & ACORES SA
# Completed:  BANCOLOMBIA SA
# Completed:  BANK OF CHILE
# Completed:  BANK OF MONTREAL /CAN/
# Completed:  Bank of N.T. Butterfield & Son Ltd
# Completed:  BANK OF NOVA SCOTIA
# Completed:  BankGuam Holding Co
# Completed:  BARCLAYS BANK PLC
# Completed:  BARCLAYS PLC
# Completed:  BBVA PREFERRED CAPITAL LTD
# Completed:  BBVA US SENIOR, S.A. UNIPERSONAL
# Completed:  BCP INTERNATIONAL BANK LTD
# Completed:  BEVERLY BANCORPORATION INC
# Completed:  Bicapital Corp
# Completed:  BSCH FINANCE LTD
# Completed:  CANADIAN IMPERIAL BANK OF COMMERCE /CAN/
# Completed:  CANADIAN IMPERIAL BANK OF COMMERCE /FI
# Completed:  Canadian Pacer Auto Receivables Trust 2017-1
# Completed:  Canadian Pacer Auto Receivables Trust 2018-1
# Completed:  AOB BIOTECH INC
# Completed:  APPALACHIAN BANCSHARES INC
# Completed:  ASHAMALLA MOUNIR R
# Completed:  ASPEN BANCSHARES INC
# Completed:  ASSOCIATED BANC-CORP
# Completed:  ASSUMPTION BANCSHARES INC
# Completed:  Atlantic Bancshares, Inc.
# Completed:  Atlantic Capital Bancshares, Inc.
# Completed:  ATLANTIC FINANCIAL CORP
# Completed:  Atlantic Union Bankshares Corp
# Completed:  AUBURN BANCORP
# Completed:  AUBURN NATIONAL BANCORPORATION, INC
# Completed:  Avenue Financial Holdings, Inc.
# Completed:  BALTIMORE BANCORP
# Completed:  BANCALABAMA INC
# Completed:  BANCO POPULAR DE PUERTO RICO /PR/
# Completed:  BANCORP HAWAII CAPITAL TRUST I
# Completed:  Bancorp of New Jersey, Inc.
# Completed:  BANCORPSOUTH INC
# Completed:  BANCORPSOUTH INC/NEW
# Completed:  BANCPLUS CORP
# Completed:  BANCTENN CORP
# Completed:  BANCWEST CAPITAL I
# Completed:  BANK BRADESCO
# Completed:  BANK CORP OF GEORGIA
# Completed:  BANK HOLDING CO
# Completed:  BANK HOLDINGS
# Completed:  Bank of Commerce Holdings
# Completed:  BANK OF GONZALES HOLDING CO INC
# Completed:  BANK OF GRANITE CORP
# Completed:  BANK OF HAWAII CORP
# Completed:  Bank of Marin Bancorp
# Completed:  BANK OF NEW HAMPSHIRE CORP
# Completed:  BANK OF NEW YORK CO INC
# Completed:  Bank of New York Mellon Corp
# Completed:  BANK OF NOVA SCOTIA
# Completed:  BANK OF SOUTH CAROLINA CORP
# Completed:  BANK OF THE JAMES FINANCIAL GROUP INC
# Completed:  BANK OF THE OZARKS INC
# Completed:  Bank7 Corp.
# Completed:  BANKERS TRUST CORP
# Completed:  BankGreenville Financial CORP
# Completed:  BANKNORTH GROUP INC/ME
# Completed:  BANKshares Inc
# Completed:  Bankwell Financial Group, Inc.
# Completed:  BANNER CORP
# Completed:  BANPONCE TRUST I
# Completed:  BANPONCE TRUST II
# Completed:  BAR HARBOR BANKSHARES
# Completed:  BARNETT BANKS INC
# Completed:  BARNETT CAPITAL II
# Completed:  BARNETT CAPITAL III
# Completed:  BARTLEIN ROBERT
# Completed:  BASLER SHIRLEY M
# Completed:  BAY AREA BANCSHARES
# Completed:  BAY BANCORP, INC.
# Completed:  BAY BANKS OF VIRGINIA INC
# Completed:  BAY COMMERCIAL SERVICES
# Completed:  BAY VIEW TRANSACTION CORP
# Completed:  BAYBANKS INC
# Completed:  BayCom Corp
# Completed:  BayFirst Financial Corp.
# Completed:  BAYLAKE CORP
# Completed:  BB&T FUNDS
# Completed:  BCB FINANCIAL SERVICES CORP /PA/
# Completed:  BEALL J HARPER III
# Completed:  BEAR STATE FINANCIAL, INC.
# Completed:  BENCHMARK BANKSHARES INC
# Completed:  BENISCH JOHN H
# Completed:  BERKSHIRE BANCORP INC /DE/
# Completed:  BEVERLY HILLS BANCORP
# Completed:  BEVERLY HILLS BANCORP INC
# Completed:  BIG LAKE FINANCIAL CORP
# Completed:  Birmingham Bloomfield Bancshares
# Completed:  BISSELL JOHN M
# Completed:  BKLA BANCORP
# Completed:  BLOOMER BANCSHARES INC
# Completed:  Blue Hills Bancorp, Inc.
# Completed:  BLUE RIDGE BANKSHARES, INC.
# Completed:  BLUE VALLEY BAN CORP
# Completed:  BM Technologies, Inc.
# Completed:  BMJ FINANCIAL CORP
# Completed:  BNH BANCSHARES INC
# Completed:  BNY CAPITAL III
# Completed:  BNY CAPITAL V
# Completed:  BODAGER BRIAN R
# Completed:  BOGGUS JAMES DONALD SR
# Completed:  BOL BANCSHARES INC
# Completed:  BORDER BANCSHARES INC
# Completed:  BOSTON BANCORP
# Completed:  Boston Private Capital Trust I
# Completed:  BOSTON PRIVATE FINANCIAL HOLDINGS INC
# Completed:  BOYLES JOHN D
# Completed:  BRACKEN FRANK A
# Completed:  BRAME JAMES B JR
# Completed:  BRIDGE VIEW BANCORP
# Completed:  Bridgewater Bancshares Inc
# Completed:  BROADWAY BANCSHARES INC
# Completed:  BROTHERHOOD BANCSHARES INC
# Completed:  BRUNSWICK BANCORP
# Completed:  BRYAN BANCORP OF GEORGIA INC
# Completed:  BRYN MAWR BANK CORP
# Completed:  BSB BANCORP INC
# Completed:  BSB Bancorp, Inc.
# Completed:  BT CAPITAL TRUST B
# Completed:  BT PREFERRED CAPITAL TRUST I
# Completed:  BUCKHEAD COMMUNITY BANCORP INC
# Completed:  BUCZEK THOMAS E
# Completed:  BURLINGAME BANCORP
# Completed:  BURNETT TIMOTHY B
# Completed:  BUSINESS BANCORP
# Completed:  Business First Bancshares, Inc.
# Completed:  BUTTON GWINNETT FINANCIAL CORP
# Completed:  BWC FINANCIAL CORP
# Completed:  BYL BANCORP
# Completed:  BYLINE BANCORP, INC.
# Completed:  C & F FINANCIAL CORP
# Completed:  C1 Financial, Inc.
# Completed:  California BanCorp
# Completed:  CALIFORNIA COMMERCIAL BANKSHARES
# Completed:  CALIFORNIA INDEPENDENT BANCORP
# Completed:  CAMBRIDGE BANCORP
# Completed:  CAMPBELL CARL L
# Completed:  Campello Bancorp, Inc.
# Completed:  Cape Bancorp, Inc.
# Completed:  CAPITAL BANCORP/FL
# Completed:  CAPITAL BANCORPORATION INC
# Completed:  CAPITAL BANK CORP
# Completed:  CAPITAL CITY BANK GROUP INC
# Completed:  CAPITAL CORP OF THE WEST
# Completed:  CAPITAL DIRECTIONS INC
# Completed:  Capital One Capital III
# Completed:  CAPITAL TRUST HOLDINGS INC.
# Completed:  CAPITALSOURCE INC
# Completed:  CapitalSouth Bancorp
# Completed:  CAPITOL CITY BANCSHARES INC
# Completed:  CapStar Financial Holdings, Inc.
# Completed:  CARDINAL BANKSHARES CORP
# Completed:  CAROLINA BANK HOLDINGS INC
# Completed:  CAROLINA FINANCIAL CORP
# Completed:  CAROLINA FIRST BANCSHARES INC
# Completed:  Carolina Trust BancShares, Inc.
# Completed:  Carroll Bancorp, Inc.
# Completed:  CASCADE BANCORP
# Completed:  CASCADE FINANCIAL CORP
# Completed:  CASTLE AMY W
# Completed:  CASTLE BANCGROUP INC
# Completed:  CASTLE DAVID B
# Completed:  CASTLE HARRY D
# Completed:  CASTLE JOHN L
# Completed:  CATHAY GENERAL BANCORP
# Completed:  CAVALRY BANCORP INC
# Completed:  CB FINANCIAL CORP
# Completed:  CB Financial CORP
# Completed:  CB Financial Services, Inc.
# Completed:  CB&T INC
# Completed:  CBC BANCORP INC
# Completed:  CBC HOLDING CO
# Completed:  CBES BANCORP INC
# Completed:  CBT CORP /KY/
# Completed:  CCB FINANCIAL CORP
# Completed:  CCCB Bancorp, Inc.
# Completed:  CCFNB BANCORP INC
# Completed:  CENTENNIAL BANCORP
# Completed:  CENTENNIAL BANCSHARES INC
# Completed:  CENTER FINANCIAL CORP
# Completed:  CENTRAL & SOUTHERN HOLDING CO/GA
# Completed:  CENTRAL BANCORP INC
# Completed:  CENTRAL BANCORP INC /MA/
# Completed:  CENTRAL BANCORPORATION /WA/
# Completed:  CENTRAL BANCORPORATION INC /TX
# Completed:  CENTRAL BANCSHARES INC
# Completed:  CENTRAL COAST BANCORP
# Completed:  CENTRAL CORP /LA/
# Completed:  CENTRAL PACIFIC FINANCIAL CORP
# Completed:  Central Pacific Financial Corp.
# Completed:  CENTRAL VALLEY COMMUNITY BANCORP
# Completed:  CENTRAL VIRGINIA BANKSHARES INC
# Completed:  CENTURY BANCORP INC
# Completed:  CERRITOS VALLEY BANCORP
# Completed:  CFB BANCORP INC
# Completed:  CFB BANCSHARES INC
# Completed:  CFB CAPITAL II
# Completed:  CFB CAPITAL III
# Completed:  CFB CAPITAL IV
# Completed:  CFB CAPITAL V
# Completed:  CHARTER BANCSHARES INC
# Completed:  CHARTER FINANCIAL CORP
# Completed:  CHASE BRIEN M
# Completed:  CHEMUNG FINANCIAL CORP
# Completed:  Chestatee Bancshares, Inc.
# Completed:  CHESTER COUNTY BANCSHARES INC
# Completed:  China Development Bank
# Completed:  CHITTENDEN CORP /VT/
# Completed:  CHOICE BANCORP, INC.
# Completed:  CHOICEONE FINANCIAL SERVICES INC
# Completed:  CIB MARINE BANCSHARES INC
# Completed:  CIRCLE BANCORP
# Completed:  CITIZENS & NORTHERN CORP
# Completed:  Citizens Bancorp
# Completed:  CITIZENS BANCORP /MD/
# Completed:  CITIZENS BANCORP OF VIRGINIA INC
# Completed:  CITIZENS BANCORP/OR
# Completed:  CITIZENS BANCSHARES CORP
# Completed:  CITIZENS BANCSHARES CORP /GA/
# Completed:  CITIZENS BANCSHARES INC /LA/
# Completed:  CITIZENS COMMUNITY BANCORP INC
# Completed:  CITIZENS CORP
# Completed:  CITIZENS FINANCIAL GROUP INC/MO
# Completed:  CITIZENS FINANCIAL GROUP INC/RI
# Completed:  CITIZENS FINANCIAL SERVICES INC
# Completed:  CITIZENS HOLDING CO /MS/
# Completed:  Citizens Independent Bancorp, Inc.
# Completed:  CITY BANCORP INC
# Completed:  CITY NATIONAL BANCSHARES Corp
# Completed:  CIVIC BANCORP
# Completed:  CIVISTA BANCSHARES, INC.
# Completed:  CIVITAS BANKGROUP INC
# Completed:  CLARK THOMAS B
# Completed:  CLOVER COMMUNITY BANKSHARES INC
# Completed:  CNB BANCSHARES INC
# Completed:  CNB FINANCIAL CORP /NY/
# Completed:  CNB FINANCIAL CORP/PA
# Completed:  CNB FINANCIAL SERVICES INC
# Completed:  COAST BANCORP
# Completed:  COAST FINANCIAL HOLDINGS INC
# Completed:  COASTAL COMMUNITY GROUP INC
# Completed:  COASTAL FINANCIAL CORP
# Completed:  COBANCORP INC
# Completed:  CODDLE CREEK FINANCIAL CORP
# Completed:  COGGIN WILLIAM HARVEY
# Completed:  COLLECTIVE INVESTMENT TRUSTS FOR UNITED MISSOURI BANK N A
# Completed:  COLONIAL BANCGROUP INC
# Completed:  COLONIAL CAPITAL II
# Completed:  COLONY BANKCORP INC
# Completed:  COLUMBIA BANCORP
# Completed:  COLUMBIA BANCORP \OR\
# Completed:  COLUMBIA BANKING SYSTEM, INC.
# Completed:  COLUMBIA FINANCIAL CORP
# Completed:  COMBANC INC
# Completed:  COMBANCORP
# Completed:  COMERICA BANK
# Completed:  COMM BANCORP INC
# Completed:  COMMERCE BANCSHARES INC /MO/
# Completed:  COMMERCE BANK NA PEORIA IL
# Completed:  COMMERCE BANK NA WICHITA KS
# Completed:  COMMERCESOUTH INC
# Completed:  COMMERCIAL BANCORP INC /FL/
# Completed:  COMMERCIAL BANCORPORATION OF COLORADO
# Completed:  COMMERCIAL BANCSHARES INC
# Completed:  COMMERCIAL BANCSHARES INC \OH\
# Completed:  COMMERCIAL BANCSHARES INC/DE/
# Completed:  COMMERCIAL BANKSHARES INC
# Completed:  COMMERCIAL NATIONAL FINANCIAL CORP /MI
# Completed:  COMMERCIAL NATIONAL FINANCIAL CORP /PA
# Completed:  COMMUNITY BANCORPORATION INC
# Completed:  COMMUNITY BANCSHARES INC /DE/
# Completed:  Community Bankers Trust Corp
# Completed:  COMMUNITY BANKSHARES INC /GA/
# Completed:  COMMUNITY BANKSHARES INC /NH/
# Completed:  COMMUNITY BANKSHARES INC /SC/
# Completed:  COMMUNITY BANKSHARES INC /VA/
# Completed:  COMMUNITY BANKSHARES OF MARYLAND INC
# Completed:  COMMUNITY CENTRAL BANK CORP
# Completed:  COMMUNITY FINANCIAL CORP /MD/
# Completed:  COMMUNITY FINANCIAL GROUP INC
# Completed:  COMMUNITY FIRST BANCORP
# Completed:  COMMUNITY FIRST BANKSHARES INC
# Completed:  COMMUNITY FIRST INC
# Completed:  Community Heritage Financial, Inc.
# Completed:  COMMUNITY SHORES BANK CORP
# Completed:  COMMUNITY TRUST BANCORP INC /KY/
# Completed:  COMMUNITY TRUST FINANCIAL SERVICES CORPORATION
# Completed:  COMMUNITY WEST BANCSHARES /
# Completed:  Congaree Bancshares Inc
# Completed:  ConnectOne Bancorp, Inc.
# Completed:  ConnectOne Bancorp, Inc.
# Completed:  CONRAD CO
# Completed:  CONTINENTAL BANCORPORATION
# Completed:  Cordia Bancorp Inc
# Completed:  CORNERSTONE FINANCIAL CORP
# Completed:  CORPUS CHRISTI BANCSHARES INC
# Completed:  County Bancorp, Inc.
# Completed:  COUNTY BANK CORP
# Completed:  COUNTY FINANCIAL CORP
# Completed:  COVENANT BANCORP INC
# Completed:  COVENANT BANCSHARES, INC.
# Completed:  COWLITZ BANCORPORATION
# Completed:  COX MICHAEL L
# Completed:  CRANDALL STEVEN D
# Completed:  CRESCENT BANKING CO
# Completed:  CROGHAN BANCSHARES INC
# Completed:  CROSSFIRST BANKSHARES, INC.
# Completed:  CROTTY RAYMOND J
# Completed:  CSB Bancorp, Inc.
# Completed:  CSRA BANK CORP
# Completed:  Customers Bancorp, Inc.
# Completed:  CVB FINANCIAL CORP
# Completed:  DANIEL GARDNER E
# Completed:  DAUPHIN DEPOSIT CORP
# Completed:  DBT HOLDING CO
# Completed:  DCB FINANCIAL CORP
# Completed:  DEARBORN BANCORP INC /MI/
# Completed:  DECATUR FIRST BANK GROUP INC
# Completed:  DEMAREE JACK L
# Completed:  DENMARK BANCSHARES INC
# Completed:  DEUTSCHE BANK AKTIENGESELLSCHAFT
# Completed:  Deutsche Bank Capital Funding Trust IX
# Completed:  Deutsche Bank Capital Funding Trust X
# Completed:  Deutsche Bank Contingent Capital Trust II
# Completed:  Deutsche Bank Contingent Capital Trust III
# Completed:  DEVOS RICHARD M /
# Completed:  DIME FINANCIAL CORP /CT/
# Completed:  DIMECO INC
# Completed:  DOLGE RICHARD M
# Completed:  DROVERS BANCSHARES CORP
# Completed:  DSA FINANCIAL CORP
# Completed:  DW BANKSHARES INC
# Completed:  EAGLE BANCORP INC
# Completed:  Eagle Bancorp Montana, Inc.
# Completed:  EAGLE FINANCIAL SERVICES INC
# Completed:  EARLY BANCSHARES INC
# Completed:  EAST PENN FINANCIAL CORP
# Completed:  EAST WEST BANCORP INC
# Completed:  EASTERN VIRGINIA BANKSHARES INC
# Completed:  EASTON BANCORP INC/MD
# Completed:  EASTSIDE HOLDING CORP
# Completed:  ECB BANCORP INC
# Completed:  EDWARDS J SCOTT
# Completed:  ELDORADO BANCORP
# Completed:  Embassy Bancorp, Inc.
# Completed:  ENTERPRISE BANCORP INC /MA/
# Completed:  ENTERPRISE FINANCIAL SERVICES CORP
# Completed:  EQUITY BANCSHARES INC
# Completed:  EXCHANGE BANCSHARES INC
# Completed:  EZ BANCORP INC
# Completed:  F&M BANCORP
# Completed:  F&M BANCORPORATION INC
# Completed:  F&M BANK CORP
# Completed:  FAIRBANCO HOLDING CO INC
# Completed:  FARLEY E PHILIP
# Completed:  FARMERS BANCORP
# Completed:  FARMERS BANCORP INC OF MARION KENTUCKY
# Completed:  FARMERS NATIONAL BANC CORP /OH/
# Completed:  FARMERS STATE BANCSHARES INC/WI
# Completed:  FAUQUIER BANKSHARES, INC.
# Completed:  FB Corp
# Completed:  FB Financial Corp
# Completed:  FBT BANCORP
# Completed:  FC BANC CORP
# Completed:  FCB NC CAPITAL TRUST I
# Completed:  FCB NC CAPITAL TRUST II
# Completed:  FCB/SC CAPITAL TRUST I
# Completed:  FCNB CAPITAL TRUST
# Completed:  FCNB CORP
# Completed:  FENTURA FINANCIAL INC
# Completed:  FIB CAPITAL TRUST
# Completed:  FIDELITY BANCORP INC
# Completed:  FIDELITY BANCSHARES NC INC /DE/
# Completed:  FIDELITY SOUTHERN CORP
# Completed:  FIFTH THIRD BANCORP
# Completed:  FIFTH THIRD CAPITAL TRUST IV
# Completed:  FIFTH THIRD CAPITAL TRUST V
# Completed:  FIFTH THIRD CAPITAL TRUST VI
# Completed:  FINANCIAL BANCSHARES INC
# Completed:  FINANCIAL CENTER BANCORP
# Completed:  FINANCIAL SERVICES CORPORATION OF THE MIDWEST
# Completed:  Finwise Bancorp
# Completed:  First Advantage Bancorp
# Completed:  FIRST AMERICAN BANCORP /AL/
# Completed:  FIRST AMERICAN BANK CORP/DE
# Completed:  FIRST BANCORP /IN/
# Completed:  FIRST BANCORP /NC/
# Completed:  FIRST BANCORP /PR/
# Completed:  FIRST BANCORP INC/
# Completed:  FIRST BANCSHARES OF TEXAS INC
# Completed:  FIRST BANKING CENTER INC
# Completed:  FIRST BANKING CO OF SOUTHEAST GEORGIA
# Completed:  FIRST BANKSHARES INC /GA/
# Completed:  FIRST BUSEY CORP /NV/
# Completed:  First Business Financial Services, Inc.
# Completed:  FIRST BUSINESS FINANCIAL SERVICES, INC.
# Completed:  First California Financial Group, Inc.
# Completed:  FIRST CAPITAL BANCORP, INC.
# Completed:  FIRST CAPITAL BANCORP, INC.
# Completed:  FIRST CARMI BANCSHARES INC
# Completed:  FIRST CENTRAL BANCSHARES INC
# Completed:  FIRST CENTURY BANKSHARES INC
# Completed:  FIRST CHATSWORTH BANKSHARES INC
# Completed:  First Choice Bancorp
# Completed:  FIRST CITIZENS BANCORPORATION INC
# Completed:  FIRST CITIZENS BANCSHARES INC /DE/
# Completed:  FIRST CITIZENS BANCSHARES INC /TN/
# Completed:  FIRST CITIZENS CRENSHAW BANCSHARES INC
# Completed:  First Citizens Financial CORP
# Completed:  FIRST CITY BANK
# Completed:  FIRST CLAYTON BANCSHARES INC
# Completed:  FIRST COLEBROOK BANCORP, INC.
# Completed:  FIRST COLONIAL BANKSHARES CORP
# Completed:  First Commerce Bancorp, Inc.
# Completed:  FIRST COMMERCE BANKS OF FLORIDA INC
# Completed:  FIRST COMMERCE COMMUNITY BANKSHARES INC
# Completed:  FIRST COMMERCIAL BANCORP INC
# Completed:  FIRST COMMERCIAL BANCSHARES INC
# Completed:  FIRST COMMUNITY BANCORP INC /GA/
# Completed:  FIRST COMMUNITY BANKING SERVICES INC
# Completed:  FIRST COMMUNITY BANKSHARES INC /VA/
# Completed:  FIRST COMMUNITY CAPITAL CORP
# Completed:  FIRST COMMUNITY CORP /SC/
# Completed:  FIRST COMMUNITY CORP /TN/
# Completed:  First Community Financial Partners, Inc.
# Completed:  FIRST DECATUR BANCSHARES INC
# Completed:  FIRST EMPIRE CAPITAL TRUST I
# Completed:  FIRST ESSEX BANCORP INC
# Completed:  FIRST FARMERS & MERCHANTS CORP
# Completed:  FIRST FIDELITY BANCORP INC
# Completed:  FIRST FINANCIAL BANCORP /CA/
# Completed:  FIRST FINANCIAL BANCORPORATION /IA/
# Completed:  FIRST FINANCIAL BANKSHARES INC
# Completed:  FIRST FINANCIAL CORP /IN/
# Completed:  FIRST FINANCIAL CORP /RI/
# Completed:  First Financial Northwest, Inc.
# Completed:  FIRST FINANCIAL SERVICE CORP
# Completed:  First Foundation Inc.
# Completed:  FIRST GEORGIA COMMUNITY CORP
# Completed:  FIRST GEORGIA HOLDING INC
# Completed:  FIRST GRAHAM BANCORP INC
# Completed:  FIRST HAWAIIAN, INC.
# Completed:  FIRST INTERNATIONAL BANCSHARES INC THRIFT INCENTIVE PLAN
# Completed:  First Internet Bancorp
# Completed:  FIRST INTERSTATE BANCSYSTEM INC
# Completed:  FIRST KEYSTONE CORP
# Completed:  FIRST LEHIGH CORP
# Completed:  FIRST LIBERTY BANCORP INC
# Completed:  FIRST M&F CORP/MS
# Completed:  FIRST MANITOWOC BANCORP INC
# Completed:  FIRST MICHIGAN BANK CORP
# Completed:  FIRST MID BANCSHARES, INC.
# Completed:  FIRST MUTUAL BANCSHARES INC
# Completed:  FIRST NATIONAL BANKSHARES OF FLORIDA INC
# Completed:  FIRST NATIONAL CORP /VA/
# Completed:  FIRST OAK BROOK BANCSHARES INC
# Completed:  FIRST OF HURON CORP
# Completed:  FIRST OTTAWA BANCSHARES, INC
# Completed:  FIRST PARAGOULD BANKSHARES INC
# Completed:  FIRST PERRY BANCORP INC /PA/
# Completed:  FIRST PLACE FINANCIAL CORP
# Completed:  FIRST PRIORITY FINANCIAL CORP.
# Completed:  FIRST REGIONAL BANCORP
# Completed:  FIRST SECURITY BANCORP INC /KY/
# Completed:  FIRST SECURITY CAPITAL II
# Completed:  FIRST SECURITY CAPITAL III
# Completed:  FIRST SECURITY CAPITAL IV
# Completed:  FIRST SECURITY CAPITAL V
# Completed:  FIRST SECURITY CORP /UT/
# Completed:  First Sentry Bancshares, Inc.
# Completed:  FIRST SHARES BANCORP INC
# Completed:  FIRST SOUTH BANCORP INC /VA/
# Completed:  FIRST SOUTH BANKCORP
# Completed:  FIRST SOUTHERN BANKSHARES INC/GA
# Completed:  FIRST STATE BANCORP INC
# Completed:  FIRST STATE BANCORPORATION
# Completed:  FIRST STATE BANCSHARES INC
# Completed:  FIRST STATE BANKING CORP
# Completed:  FIRST STATE CAPITAL CORP
# Completed:  FIRST STATE CORP /GA/
# Completed:  FIRST STATE FINANCIAL CORP
# Completed:  FIRST STATE FINANCIAL CORP/FL
# Completed:  FIRST UNION BANCORP /GA/
# Completed:  FIRST US BANCSHARES, INC.
# Completed:  FIRST VIRGINIA BANKS INC
# Completed:  FIRST WEST VIRGINIA BANCORP INC
# Completed:  First Western Financial Inc
# Completed:  FIRSTAR HOME MORTGAGE CORP
# Completed:  FIRSTBANK CORP
# Completed:  FIRSTBANK OF ILLINOIS CO
# Completed:  FIRSTFED BANCORP INC
# Completed:  FIRSTIER CORP
# Completed:  FIVE STAR BANCORP
# Completed:  Florida Bank Group, Inc.
# Completed:  FLORIDA BUSINESS BANCGROUP INC
# Completed:  FLORIDA COMMUNITY BANKS INC
# Completed:  FLORIDIAN FINANCIAL GROUP INC
# Completed:  FLUSHING FINANCIAL CORP
# Completed:  FNB BANCORP/CA/
# Completed:  FOOTHILL INDEPENDENT BANCORP
# Completed:  FORESIGHT FINANCIAL GROUP INC
# Completed:  FORSYTH BANCSHARES INC
# Completed:  FORT BANCORP INC
# Completed:  FORT BROOKE BANCORPORATION
# Completed:  FOUR OAKS FINCORP INC
# Completed:  FOX SHELDON M
# Completed:  FP BANCORP INC
# Completed:  FRANKLIN BANCORP INC
# Completed:  FRANKLIN BANCORP INC MI
# Completed:  Franklin Financial Network Inc.
# Completed:  FRANKLIN FINANCIAL SERVICES CORP /PA/
# Completed:  FREEDOM BANCSHARES INC
# Completed:  FREEDOM FINANCIAL CORPORATION/IN/
# Completed:  FREMONT BANCORPORATION
# Completed:  FRONTIER FINANCIAL CORP /WA/
# Completed:  FSB BANCORP INC
# Completed:  FURR RICHARD L
# Completed:  FURY MICHAEL H
# Completed:  FVCBankcorp, Inc.
# Completed:  GALLIHER DAVID A
# Completed:  GARDEN STATE BANCSHARES INC
# Completed:  GARDINER THOMAS K
# Completed:  GARLICK RALPH W
# Completed:  GARRETT BLAKE P JR
# Completed:  GATES REEDER D
# Completed:  GATEWAY BANCSHARES INC
# Completed:  GATEWAY BANCSHARES INC /GA/
# Completed:  Gateway Pacific Bancorp
# Completed:  GAYLES LEILANI
# Completed:  GB&T BANCSHARES INC
# Completed:  GBC BANCORP
# Completed:  GBC BANCORP INC
# Completed:  GBT BANCORP
# Completed:  Georgetown Bancorp, Inc.
# Completed:  GEORGIA BANCSHARES INC /GA/
# Completed:  GEORGIA BANCSHARES INC//
# Completed:  Georgia-Carolina Bancshares, Inc
# Completed:  GERMAN AMERICAN BANCORP, INC.
# Completed:  GILCREST ROGER W
# Completed:  GLACIER BANCORP INC /WA
# Completed:  GLACIER BANCORP, INC.
# Completed:  GLB BANCORP INC
# Completed:  GLEN BURNIE BANCORP
# Completed:  GNB FINANCIAL SERVICES INC
# Completed:  Golden Mountain Financial Corp
# Completed:  GOLDENBANKS OF COLORADO INC
# Completed:  GOODALL HURLEY C
# Completed:  GRAND RIVER COMMERCE INC
# Completed:  GRANDBANC INC
# Completed:  GRANITE STATE BANKSHARES INC
# Completed:  GREAT GUARANTY BANCSHARES INC
# Completed:  GREAT SOUTHERN BANCORP, INC.
# Completed:  Great Western Bancorp, Inc.
# Completed:  GREATER COMMUNITY BANCORP
# Completed:  GREATER ROME BANCSHARES INC
# Completed:  GREEN BANKSHARES, INC.
# Completed:  GREENE STANLEE P JR
# Completed:  GREENPOINT CAPITAL TRUST I
# Completed:  GRENADA SUNBURST SYSTEM CORP
# Completed:  GRISWOLD WILLIAM W
# Completed:  GROWTH FINANCIAL CORP
# Completed:  Guaranty Bancorp
# Completed:  GUARANTY BANCSHARES HOLDING CORP
# Completed:  GUARANTY BANCSHARES INC
# Completed:  GUARANTY FEDERAL BANCSHARES INC
# Completed:  GUARANTY STATE BANCORP
# Completed:  GUARDIAN BANCORP
# Completed:  GULF WEST BANKS INC
# Completed:  HABERSHAM BANCORP
# Completed:  HACKETT JAMES P
# Completed:  HALES THOMAS E
# Completed:  HAMILTON BANCORP INC/FL
# Completed:  HANCOCK WHITNEY CORP
# Completed:  HANKA ERINA
# Completed:  HANOVER BANCORP INC
# Completed:  Hanover Bancorp, Inc. /NY
# Completed:  HARBOR BANCORP /
# Completed:  HARBOR BANKSHARES CORP
# Completed:  HarborOne Bancorp, Inc.
# Completed:  HarborOne Bancorp, Inc./OLD
# Completed:  HARDWICK HOLDING CO
# Completed:  HARRIS BANKCORP INC
# Completed:  HARTMEYER JOHN W
# Completed:  HAWKEYE BANCORPORATION
# Completed:  HBT Financial, Inc.
# Completed:  HCB FINANCIAL CORP
# Completed:  HCBF Holding Company, Inc.
# Completed:  HCSB FINANCIAL CORP
# Completed:  HEARTLAND BANCSHARES INC /IN/
# Completed:  HEARTLAND FINANCIAL USA INC
# Completed:  HEINRICHS NELSON W
# Completed:  HELMS LARRY R
# Completed:  HEMET BANCORP
# Completed:  HENRY COUNTY BANCSHARES INC
# Completed:  HERITAGE BANCORP INC
# Completed:  HERITAGE BANCORP INC /PA/
# Completed:  HERITAGE BANCORP INC /VA/
# Completed:  HERITAGE BANCSHARES INC /WV/
# Completed:  HERITAGE BANKSHARES INC /VA
# Completed:  HERITAGE COMMERCE CORP
# Completed:  HERITAGE FINANCIAL SERVICES INC /IL/
# Completed:  HERITAGE FINANCIAL SERVICES INC /TN/
# Completed:  HERITAGE OAKS BANCORP
# Completed:  HERSHARE FINANCIAL CORP
# Completed:  HIGH POINT FINANCIAL CORP
# Completed:  HIGH POINT FINANCIAL SERVICES INC /IL
# Completed:  HIGHLANDS BANCORP, INC.
# Completed:  HIGHLANDS BANKSHARES INC /VA/
# Completed:  HIGHLANDS BANKSHARES INC /WV/
# Completed:  HILLS BANCORPORATION
# Completed:  Hilltop Holdings Inc.
# Completed:  HNB FINANCIAL GROUP
# Completed:  HOLDER E V JR
# Completed:  HOLMES EDWARD S
# Completed:  HOME BANCSHARES INC
# Completed:  HOME FEDERAL CORP
# Completed:  HOME INTERSTATE BANCORP
# Completed:  HomeStreet, Inc.
# Completed:  HOMETOWN BANCORPORATION INC
# Completed:  HOMETOWN BANCSHARES INC
# Completed:  HomeTown Bankshares Corp
# Completed:  HOOKS EDWARD C
# Completed:  HOOVER PAUL R
# Completed:  HOPFED BANCORP INC
# Completed:  HORIZON BANCORP INC /IN/
# Completed:  HORIZON BANCORP INC /WV/
# Completed:  HORIZON FINANCIAL CORP
# Completed:  HOWARD BANCORP
# Completed:  Howard Bancorp Inc
# Completed:  HOWELL BONNIE H
# Completed:  HSBC USA INC
# Completed:  HUBCO CAPITAL TRUST I
# Completed:  HUBCO CAPITAL TRUST II
# Completed:  HUDSON UNITED BANCORP
# Completed:  HUDSON VALLEY HOLDING CORP
# Completed:  HUMBOLDT BANCORP
# Completed:  HURON COMMUNITY FINANCIAL SERVICES INC
# Completed:  HV Bancorp, Inc.
# Completed:  IBC CAPITAL FINANCE
# Completed:  IBERIABANK CORP
# Completed:  IBT BANCORP INC
# Completed:  IFC CAPITAL TRUST I
# Completed:  ILLGEN JOHN D
# Completed:  ILLINI CORP
# Completed:  IMPERIAL BANCORP
# Completed:  IMPERIAL BANK /CA/
# Completed:  IMPERIAL CAPITAL BANCORP, INC.
# Completed:  IMPERIAL FINANCIAL GROUP INC
# Completed:  INDEPENDENCE BANCORP INC /NJ/
# Completed:  INDEPENDENT BANCORP OF ARIZONA INC
# Completed:  INDEPENDENT BANK CORP
# Completed:  INDEPENDENT BANK CORP /MI/
# Completed:  Independent Bank Group, Inc.
# Completed:  INDEPENDENT FINANCIAL NETWORK
# Completed:  Infinity Bancorp
# Completed:  INTEGRA BANK CORP
# Completed:  INTEGRA FINANCIAL CORP
# Completed:  INTEGRITY FINANCIAL CORP
# Completed:  INTERNATIONAL BANCSHARES CORP
# Completed:  INTRUST FINANCIAL CORP /
# Completed:  Investar Holding Corp
# Completed:  Investors Bancorp, Inc.
# Completed:  IOWA FIRST BANCSHARES CORP
# Completed:  IRON & GLASS BANCORP INC
# Completed:  IRWIN FINANCIAL CORP
# Completed:  ISABELLA BANK Corp
# Completed:  ISB BANCSHARES INC
# Completed:  Itau Unibanco Holding S.A.
# Completed:  IUB CAPITAL TRUST
# Completed:  JACKSONVILLE BANCORP INC /FL/
# Completed:  JAMES RIVER BANKSHARES INC
# Completed:  JANDERNOA MICHAEL J
# Completed:  JD BANCSHARES INC
# Completed:  JEANERETTE FIRST NATIONAL BANCORP INC
# Completed:  JEFFBANKS INC
# Completed:  JEFFERSON BANCORP INC
# Completed:  JEFFERSON BANKSHARES INC
# Completed:  JENKINS WILBUR
# Completed:  John Marshall Bancorp, Inc.
# Completed:  JOYNER C DAN
# Completed:  JUNIATA VALLEY FINANCIAL CORP
# Completed:  KABAT KEVIN T
# Completed:  KASSIN CLARITA
# Completed:  KATAHDIN BANKSHARES CORP
# Completed:  KELLER JOHN P
# Completed:  KELLY J HOWELL
# Completed:  KENTUCKY BANCSHARES INC /KY/
# Completed:  KERSTEIN DAVID L
# Completed:  KEY CAPITAL CORP
# Completed:  KINGFISHER BANCORP INC
# Completed:  KREI KENNETH C
# Completed:  LAFAYETTE BANCORPORATION
# Completed:  LAKE SHORE BANCORP INC
# Completed:  LAKELAND BANCORP INC
# Completed:  LAKELAND FINANCIAL CORP
# Completed:  LAMAR CAPITAL CORP
# Completed:  LAWRENCE SAVINGS
# Completed:  LCS BANCORP INC
# Completed:  LEGENDS FINANCIAL HOLDINGS INC
# Completed:  MID MISSOURI HOLDING CO INC
# Completed:  MID PENN BANCORP INC
# Completed:  MID WISCONSIN FINANCIAL SERVICES INC
# Completed:  Mid-America Bancshares, Inc.
# Completed:  MID-STATE BANCSHARES
# Completed:  MIDCAROLINA FINANCIAL CORP
# Completed:  MIDDLEFIELD BANC CORP
# Completed:  Midland States Bancorp, Inc.
# Completed:  Midstate Bancorp, Inc.
# Completed:  Midwest Bancshares, Inc.
# Completed:  MIDWESTONE FINANCIAL GROUP INC
# Completed:  MidWestOne Financial Group, Inc.
# Completed:  MISSISSIPPI VALLEY BANCSHARES INC
# Completed:  MISTRETTA JOHN J
# Completed:  MOLIHAN KEITH F
# Completed:  MOLL JON H
# Completed:  Monarch Financial Holdings, Inc.
# Completed:  MONROE BANCORP
# Completed:  MORGAN FINANCIAL CORP
# Completed:  MORGAN J P & CO INC
# Completed:  MORROW GEORGE J
# Completed:  MOUND CITY FINANCIAL SERVICES INC
# Completed:  MUNSON ERIC B
# Completed:  MUTUALFIRST FINANCIAL INC
# Completed:  MVB FINANCIAL CORP
# Completed:  MW Bancorp, Inc.
# Completed:  NATIONAL MERCANTILE BANCORP
# Completed:  NELLIS MICHEL
# Completed:  NEW ENGLAND COMMUNITY BANCORP INC
# Completed:  NEW IBERIA BANCORP INC
# Completed:  NEW MEXICO BANQUEST CORP
# Completed:  NEW PEOPLES BANKSHARES INC
# Completed:  NEWBRIDGE BANCORP
# Completed:  NEXITY FINANCIAL CORP
# Completed:  NMBT CORP
# Completed:  NORTH CASCADES BANCSHARES INC
# Completed:  NORTH COUNTY BANCORP
# Completed:  NORTH FORK BANCORPORATION INC
# Completed:  NORTH GEORGIA COMMUNITY FINANCIAL PARTNE
# Completed:  NORTH STATE BANCORP
# Completed:  NORTH VALLEY BANCORP
# Completed:  NORTHEAST BANCORP /ME/
# Completed:  NORTHERN BANCORP INC
# Completed:  NORTHERN CALIFORNIA BANCORP INC
# Completed:  NORTHERN ILLINOIS FINANCIAL CORP
# Completed:  NORTHERN STAR FINANCIAL INC
# Completed:  NORTHERN STATES FINANCIAL CORP /DE/
# Completed:  NORTHERN TRUST CORP
# Completed:  NORWOOD FINANCIAL CORP
# Completed:  NSD BANCORP INC
# Completed:  NTC CAPITAL I
# Completed:  NUMERICA FINANCIAL CORP
# Completed:  NW SERVICES CORP
# Completed:  O A K FINANCIAL CORP
# Completed:  OAK HILL FINANCIAL INC
# Completed:  Oak Valley Bancorp
# Completed:  OCONEE FINANCIAL CORP
# Completed:  OFG BANCORP
# Completed:  OHIO STATE BANCSHARES INC
# Completed:  OHIO VALLEY BANC CORP
# Completed:  OHIO VALLEY BANCORP
# Completed:  OLD KENT FINANCIAL CORP /MI/
# Completed:  OLD LINE BANCSHARES INC
# Completed:  OLD SECOND BANCORP INC
# Completed:  OLYMPUS CAPITAL CORP /UT/
# Completed:  ONBANCORP INC
# Completed:  ONE AMERICAN CORP
# Completed:  ONE VALLEY BANCORP INC
# Completed:  OP Bancorp
# Completed:  Orange County Bancorp, Inc. /DE/
# Completed:  Origin Bancorp, Inc.
# Completed:  Oritani Financial Corp
# Completed:  Oritani Financial Corp.
# Completed:  ORRSTOWN FINANCIAL SERVICES INC
# Completed:  OWEN FINANCIAL CORP
# Completed:  OZARK CAPITAL TRUST
# Completed:  P B FINANCIAL SERVICES CORP
# Completed:  PAB BANKSHARES INC
# Completed:  PACIFIC CAPITAL BANCORP
# Completed:  PACIFIC CAPITAL BANCORP /CA/
# Completed:  PACIFIC COMMUNITY BANKING GROUP
# Completed:  PACIFIC FINANCIAL CORP
# Completed:  PACIFIC NORTHWEST BANCORP
# Completed:  PACIFIC PREMIER BANCORP INC
# Completed:  Pacific Premier Bank
# Completed:  PADUCAH BANK SHARES INC
# Completed:  PALMETTO BANCSHARES INC
# Completed:  PALMETTO BANK TRUSTEE FOR THE EMPLOYEE STOCK OWNERSHIP PLAN
# Completed:  PARADIGM BANCORPORATION INC
# Completed:  Paragon Commercial CORP
# Completed:  PARFET WILLIAM U /
# Completed:  Park Sterling Corp
# Completed:  PARKE BANCORP, INC.
# Completed:  PARKER W HAROLD JR
# Completed:  PARTNERS BANCORP
# Completed:  PATAPSCO VALLEY BANCSHARES INC
# Completed:  Pathfinder Bancorp, Inc.
# Completed:  PCB BANCORP
# Completed:  PCB BANCORP INC
# Completed:  PENN LAUREL FINANCIAL CORP
# Completed:  PENNS WOODS BANCORP INC
# Completed:  PENSECO FINANCIAL SERVICES CORP
# Completed:  PEOPLES BANCORP
# Completed:  PEOPLES BANCORP INC
# Completed:  PEOPLES BANCORP INC /GA/
# Completed:  PEOPLES BANCORP INC \TX\
# Completed:  PEOPLES BANCORP OF NORTH CAROLINA INC
# Completed:  PEOPLES BANCSHARES OF POINTE COUPEE PARISH INC
# Completed:  PEOPLES BANCTRUST CO INC
# Completed:  PEOPLES BANK /OH
# Completed:  PEOPLES BANK CORP OF INDIANAPOLIS
# Completed:  PEOPLES BANKSHARES INC/GA/
# Completed:  PEOPLES COMMUNITY CAPITAL CORP
# Completed:  PEOPLES FINANCIAL CORP /MS/
# Completed:  PEOPLES FINANCIAL CORP INC /PA/
# Completed:  PEOPLES HERITAGE CAPITAL TRUST I
# Completed:  PEOPLES LTD
# Completed:  PERRY JOSEPH H
# Completed:  PFGI CAPITAL CORP
# Completed:  Piedmont Community Bank Group, Inc.
# Completed:  PIERRE PERCY A
# Completed:  Pilgrim Bancshares, Inc.
# Completed:  PILYPEC LEO P
# Completed:  PINNACLE BANCSHARES INC
# Completed:  PINNACLE FINANCIAL CORP
# Completed:  PINNACLE FINANCIAL SERVICES INC
# Completed:  PIONEER BANCORPORATION
# Completed:  PIONEER BANCSHARES INC
# Completed:  Pioneer Bancshares, Inc.
# Completed:  PIONEER BANKCORP INC
# Completed:  PLACER SIERRA BANCSHARES
# Completed:  PLAINSCAPITAL CORP
# Completed:  Planters Holding Co
# Completed:  PNB FINANCIAL GROUP
# Completed:  POINTE FINANCIAL CORP
# Completed:  POPULAR NORTH AMERICA INC
# Completed:  POPULAR, INC.
# Completed:  POTOMAC BANCSHARES INC
# Completed:  PREMIER BANCORP INC /PA/
# Completed:  PREMIER BANCSHARES INC /GA
# Completed:  PREMIER FINANCIAL BANCORP INC
# Completed:  PREMIER FINANCIAL CORP
# Completed:  PREMIER FINANCIAL SERVICES INC
# Completed:  PRESTIGE FINANCIAL CORP
# Completed:  PRIME BANCSHARES INC /TX/
# Completed:  Prime Meridian Holding Co
# Completed:  Primis Financial Corp.
# Completed:  Princeton Bancorp, Inc.
# Completed:  PRIVATEBANCORP CAPITAL TRUST IV
# Completed:  PRIVATEBANCORP, INC
# Completed:  Pro Financial Holdings Inc
# Completed:  PROFESSIONAL BANCORP INC
# Completed:  PROGRESSIVE BANK INC
# Completed:  PROMISTAR FINANCIAL CORP
# Completed:  PROSPERITY BANCSHARES INC
# Completed:  PROVIDENT BANKSHARES CORP
# Completed:  PROVIDENT CAPITAL TRUST I
# Completed:  PROVIDENT CAPITAL TRUST II
# Completed:  PROVIDENT CAPITAL TRUST III
# Completed:  PROVIDENT CAPITAL TRUST IV
# Completed:  PROVIDENT FINANCIAL GROUP INC
# Completed:  PROVIDENT TRUST I
# Completed:  PROVIDENT TRUST II
# Completed:  PSB BANCGROUP INC
# Completed:  PSB HOLDINGS INC /WI/
# Completed:  PTC BANCORP
# Completed:  PUGET SOUND BANCORP
# Completed:  PUGH BEN T
# Completed:  PULLON LYNDA K
# Completed:  PYRAMIDWEST DEVELOPMENT CORP
# Completed:  QCB BANCORP
# Completed:  QCR HOLDINGS INC
# Completed:  QNB CORP
# Completed:  QUANTUM CAPITAL CORP/GA
# Completed:  R&G FINANCIAL CORP
# Completed:  RADY JAMES
# Completed:  RAINIER PACIFIC FINANCIAL GROUP INC
# Completed:  RAMAPO FINANCIAL CORP
# Completed:  Randolph Bancorp, Inc.
# Completed:  RAWLINGS HUNTER R III
# Completed:  RBB Bancorp
# Completed:  RED BUD BANCORP INC
# Completed:  RED RIVER BANCSHARES INC
# Completed:  REGENCY BANCORP
# Completed:  RELIABLE COMMUNITY BANCSHARES INC
# Completed:  Reliant Bancorp, Inc.
# Completed:  RENASANT CORP
# Completed:  REPUBLIC BANCORP INC
# Completed:  REPUBLIC BANCORP INC /KY/
# Completed:  REPUBLIC BANCSHARES INC
# Completed:  REPUBLIC BANCSHARES OF TEXAS INC
# Completed:  REPUBLIC BANKING CORP OF FLORIDA
# Completed:  REPUBLIC CAPITAL TRUST I
# Completed:  REPUBLIC FIRST BANCORP INC
# Completed:  RICHARDSON MICHAEL G
# Completed:  RICHLAND COUNTY BANCSHARES INC
# Completed:  Richmond Mutual Bancorporation, Inc.
# Completed:  RICHWOOD BANCSHARES INC
# Completed:  RIDGESTONE FINANCIAL SERVICES INC
# Completed:  RIVA BANCSHARES INC
# Completed:  River Financial Corp
# Completed:  ROESSLER ERNEST C
# Completed:  ROYAL BANCSHARES OF PENNSYLVANIA INC
# Completed:  Royal Bancshares, Inc.
# Completed:  RUDERMAN HOWARD V
# Completed:  S&T BANCORP INC
# Completed:  SABATINI STEVEN T
# Completed:  SADLER ROBERT L
# Completed:  SAFETY FUND CORP
# Completed:  SALM THOMAS R
# Completed:  SAN FRANCISCO CO
# Completed:  SAN JOAQUIN BANCORP
# Completed:  SANDERS WILLIAM L
# Completed:  SANDWICH BANCORP INC
# Completed:  Santa Lucia Bancorp
# Completed:  SANTA MONICA BANK
# Completed:  SARASOTA BANCORPORATION INC / FL
# Completed:  SARATOGA BANCORP
# Completed:  SATILLA FINANCIAL SERVICES INC
# Completed:  SAVERS INC
# Completed:  SB FINANCIAL GROUP, INC.
# Completed:  SB ONE BANCORP
# Completed:  SBT Bancorp, Inc.
# Completed:  SC BANCORP
# Completed:  SCAGGS NEAL
# Completed:  SCB BANCORP INC
# Completed:  SDN BANCORP
# Completed:  SDNB FINANCIAL CORP
# Completed:  SEACOAST BANKING CORP OF FLORIDA
# Completed:  SEAWAY FINANCIAL CORP
# Completed:  SECONN HOLDING CO
# Completed:  Securitized Term Auto Receivables Trust 2017-2
# Completed:  Securitized Term Auto Receivables Trust 2018-1
# Completed:  SECURITY BANC CORP
# Completed:  SECURITY BANCSHARES INC
# Completed:  SECURITY BANK CORP
# Completed:  SECURITY CAPITAL BANCORP
# Completed:  SECURITY CHICAGO CORP
# Completed:  SECURITY FEDERAL CORP
# Completed:  SECURITY FINANCIAL CORP /OH/
# Completed:  SECURITY STATE BANCSHARES INC
# Completed:  SELECT BANCORP, INC.
# Completed:  Semoran Financial CORP
# Completed:  Seneca-Cayuga Bancorp, Inc.
# Completed:  SERVICE 1ST BANCORP
# Completed:  SERVICE BANCORP INC
# Completed:  ServisFirst Bancshares, Inc.
# Completed:  SEVIER COUNTY BANCSHARES, INC.
# Completed:  SHAFFER C RANDY
# Completed:  SHAY MICHAEL D
# Completed:  SHERWOOD B P III
# Completed:  SHI DAVID E
# Completed:  SHORE FINANCIAL CORP
# Completed:  SIERRA BANCORP
# Completed:  SIERRAWEST BANCORP
# Completed:  Signature Bank Corp
# Completed:  Silver State Bancorp
# Completed:  Silvergate Capital Corp
# Completed:  SIMS JAMES R JR
# Completed:  SISSEL GEORGE A
# Completed:  SJNB FINANCIAL CORP
# Completed:  Skagit State Bancorp, Inc.
# Completed:  SKANEATELES BANCORP INC
# Completed:  Skyline Bankshares, Inc.
# Completed:  SLADES FERRY BANCORP
# Completed:  SMITH THOMAS J//
# Completed:  SMITHTOWN BANCORP INC
# Completed:  SMITSON ROBERT M
# Completed:  SOLVAY BANK CORP
# Completed:  SOMERSET HILLS BANCORP
# Completed:  Sonata Financial Holdings, Inc.
# Completed:  SOPERTON BANCSHARES Inc
# Completed:  SOUTH BANKING CO
# Completed:  SOUTH FINANCIAL GROUP INC
# Completed:  SOUTH FLORIDA BANK HOLDING CORPORATION
# Completed:  SOUTH PLAINS FINANCIAL, INC.
# Completed:  South Valley Bancorp, Inc.
# Completed:  SOUTH VALLEY BANCORPORATION
# Completed:  TAYLOR CALVIN B BANKSHARES INC
# Completed:  TAYLOR CAPITAL GROUP INC
# Completed:  TD BANKNORTH INC.
# Completed:  TECHE BANCSHARES INC
# Completed:  TECHE HOLDING CO
# ...
# Completed:  World Monitor Trust III - Series H
# Completed:  World Monitor Trust III - Series I
# Completed:  World Monitor Trust III - Series J
# Completed:  WORLD MONITOR TRUST SERIES A
# Completed:  WORLD MONITOR TRUST SERIES B
# Completed:  WORLD MONITOR TRUST SERIES C
# Completed:  wShares Bitcoin Fund
# Completed:  wShares Enhanced Gold ETF
# Completed:  ABBOTT FRANK H III
# Completed:  AFFILIATED MANAGERS GROUP, INC.
# Completed:  AGBA Group Holding Ltd.
# Completed:  ALLIANCE CAPITAL MANAGEMENT LP II
# Completed:  ALLIANCEBERNSTEIN HOLDING L.P.
# Completed:  ALLIANCEBERNSTEIN L.P.
# Completed:  Allianz Asset Management of America L.P.
# Completed:  ALLIED CAPITAL ADVISERS INC
# Completed:  Alvarium Tiedemann Holdings, Inc.
# Completed:  AMERIPRISE FINANCIAL INC
# Completed:  AMG Capital Trust I
# Completed:  AMRESCO RESIDENTIAL SECS CORP MORT LOAN TRUST 1998-3
# Completed:  AMRESCO RESIDENTIAL SECURITIES CORP MORT LOAN TRUST 1997-3
# Completed:  AMRESCO RESIDENTIAL SECURITIES CORP MORTGAGE LOAN TR 1998-1
# Completed:  AMRESCO RESIDENTIAL SECURITIES CORP MORTGAGE LOAN TR 1998-2
# Completed:  AMUNDI PIONEER ASSET MANAGEMENT USA, INC.
# Completed:  AMVESCAP PLC
# Completed:  Apollo Asset Management, Inc.
# Completed:  Apollo Global Management, Inc.
# Completed:  Ares Management Corp
# Completed:  Artio Global Investors Inc.
# Completed:  Artisan Partners Asset Management Inc.
# Completed:  AssetMark Financial Holdings, Inc.
# Completed:  AWA Group LP
# Completed:  B. Riley Financial, Inc.
# Completed:  BAIO JAMES R
# Completed:  BCI HOLDING INC
# Completed:  BIOTECHNOLOGY VALUE FUND L P
# Completed:  BKF CAPITAL GROUP INC
# Completed:  BlackRock Holdco 2, Inc.
# Completed:  Blackstone Inc.
# Completed:  BLUE OWL CAPITAL INC.
# Completed:  BNY Mellon Investment Adviser, Inc.
# Completed:  BOSTON PARTNERS ASSET MANAGEMENT LLC
# Completed:  Bridge Investment Group Holdings Inc.
# Completed:  BrightSphere Inc.
# Completed:  BrightSphere Investment Group Inc.
# Completed:  BrightSphere Investment Group plc
# Completed:  Brookfield Asset Management Ltd.
# Completed:  CARLSON ROBERT F
# Completed:  Carlyle Group Inc.
# Completed:  CF Finance Acquisition Corp.
# Completed:  CHAPMAN CAPITAL MANAGEMENT HOLDINGS INC
# Completed:  CI Financial Corp.
# Completed:  CLEAR CHOICE FINANCIAL, INC.
# Completed:  CNL Strategic Capital, LLC
# Completed:  COHEN & STEERS, INC.
# Completed:  COLONIAL GROUP INC /MA/
# Completed:  CONNING INC.
# Completed:  CONVERGENT TECHNOLOGY GROUP INC
# Completed:  CORNERSTONE MANAGEMENT, INC.
# Completed:  DELTA CLEARING CORP /DE/
# Completed:  DIAMOND HILL INVESTMENT GROUP INC
# Completed:  DUNDEE CORP
# Completed:  Dynasty Financial Partners Inc.
# Completed:  East Resources Acquisition Co
# Completed:  ENDI Corp.
# Completed:  EPOCH HOLDING CORP
# Completed:  Evercore Inc.
# Completed:  FEDERATED HERMES, INC.
# Completed:  FEDERATED INVESTORS /DE
# Completed:  Fifth Street Asset Management Inc.
# Completed:  Financial Engines, LLC
# Completed:  Focus Financial Partners Inc.
# Completed:  FORESTER SAMUEL J JR
# Completed:  Fortress Investment Group LLC
# Completed:  FORTUNATO S JOSEPH
# Completed:  FRANKLIN RESOURCES INC
# Completed:  FRMO CORP
# Completed:  GALBRAITH JOHN W
# Completed:  GCM Grosvenor Inc.
# Completed:  Gladstone Companies, Inc.
# Completed:  GlassBridge Enterprises, Inc.
# Completed:  GLG Partners, Inc.
# Completed:  GLOBAL DECISIONS GROUP LLC
# Completed:  GOSS DAVID P
# Completed:  GREEN BARBARA J
# Completed:  GUNDAKER/JORDAN AMERICAN HOLDINGS INC
# Completed:  Hamilton Lane INC
# Completed:  HENNESSY ADVISORS INC
# Completed:  HIGHBURY FINANCIAL INC
# Completed:  HINES ANDREW H JR
# Completed:  HOLOWESKO MARK G
# Completed:  HOULIHAN LOKEY, INC.
# Completed:  Hywin Holdings Ltd.
# Completed:  Institute for Wealth Holdings, Inc.
# Completed:  Interactive Data Holdings Corp
# Completed:  INTREPID CAPITAL CORP
# Completed:  Invesco Advisers, Inc.
# Completed:  Invesco Aim Advisors, Inc.
# Completed:  Invesco Ltd.
# Completed:  Invesco Management Group, Inc.
# Completed:  INVESTORS FINANCIAL SERVICES CORP
# Completed:  JAMIESON EDWARD B
# Completed:  JANUS CAPITAL GROUP INC
# Completed:  JANUS HENDERSON GROUP PLC
# Completed:  KB Global Holdings Ltd
# Completed:  KENNY THOMAS J
# Completed:  KEYSTONE INVESTMENT MANAGEMENT CO
# Completed:  KEYSTONE INVESTMENTS INC
# Completed:  KingsCrowd, Inc.
# Completed:  KKR & Co. Inc.
# Completed:  KKR Group Partnership L.P.
# Completed:  KNOBIAS, INC.
# Completed:  Lazard Group LLC
# Completed:  Lazard Ltd
# Completed:  LEGG MASON, INC.
# Completed:  Legion Capital Corp
# Completed:  LIM DENNIS
# Completed:  LUFKIN CHAUNCEY F
# Completed:  MACKENZIE FINANCIAL CORP
# Completed:  MACKLIN GORDON S
# Completed:  MACQUARIE MANAGEMENT HOLDINGS, INC.
# Completed:  Manning & Napier, Inc.
# Completed:  MCGOWAN GREGORY E
# Completed:  MCVEY EDWARD V
# Completed:  Medley LLC
# Completed:  MEDLEY MANAGEMENT INC.
# Completed:  MILLSAPS FRED R
# Completed:  Mirror Merger Sub 2, LLC
# Completed:  MOBIUS J MARK
# Completed:  Moelis & Co
# Completed:  MOLUMPHY CHRIS
# Completed:  MONASTERIO KIMBERLY
# Completed:  FARM FISH INC
# Completed:  Greenfield Farms Food, Inc.
# Completed:  MARICULTURE SYSTEMS INC
# Completed:  Maritek Corp
# Completed:  MICHAEL FOODS INC
# Completed:  NanoTech Entertainment, Inc.
# Completed:  NEPTUNE INDUSTRIES, INC.
# Completed:  NOCERA, INC.
# Completed:  OPUS COMMUNITIES, INC.
# Completed:  POWERNOMICS ENTERPRISE CORP
# Completed:  PRIMELINK SYSTEMS INC
# Completed:  Rainbow Coral Corp.
# Completed:  SADIA S.A.
# Completed:  SEN YU INTERNATIONAL HOLDINGS, INC.
# Completed:  SOUTHERN CHINA LIVESTOCK, INC.
# Completed:  SPENDTHRIFT FARM INC
# Completed:  TEXMONT INC
# Completed:  tru Shrimp Companies, Inc.
# Completed:  U. S. Premium Beef, LLC
# Completed:  Union Agriculture Group Corp.
# Completed:  WHITEFORD PARTNERS L P
# Completed:  Yotta Acquisition Corp
# Completed:  ADDISSON INDUSTRIES INC
# Completed:  AGRI LAND REALTY INC
# Completed:  Agrify Corp
# Completed:  American Critter College, Inc.
# Completed:  Apex Farms Corp.
# Completed:  Arysta LifeScience plc
# Completed:  BAREFOOT INC /DE
# Completed:  BIG VALLEY LEASING INC
# Completed:  BIONOVA HOLDING CORP
# Completed:  BRICKMAN GROUP LTD
# Completed:  BrightView Holdings, Inc.
# Completed:  CALAVO GROWERS INC
# Completed:  Cavitation Technologies, Inc.
# Completed:  CEA Industries Inc.
# Completed:  Ceres Global Ag Corp.
# Completed:  CHASE PACKAGING CORP
# Completed:  COACHELLA GROWERS INC
# Completed:  DAVEY TREE EXPERT CO
# Completed:  DDS HOLDINGS INC
# Completed:  DINUBA PACKING CORP
# Completed:  DIONICS INC
# Completed:  ECO SOIL SYSTEMS INC
# Completed:  FIRST XERIS CORP.
# Completed:  FITWEISER HOLDINGS, INC.
# Completed:  Golden Growers Cooperative
# Completed:  GP SOLUTIONS INC
# Completed:  Green Asia Resources Inc
# Completed:  Green Grass Ecological Technology Development Co., Ltd.
# Completed:  GREEN SOLUTIONS CHINA, INC.
# Completed:  GreenPlex Services, Inc.
# Completed:  GroGenesis, Inc.
# Completed:  HINES NURSERIES INC
# Completed:  HLS USA INC
# Completed:  INSPIRE VETERINARY PARTNERS, INC.
# Completed:  LANDCARE USA INC
# Completed:  Lotus Bio-Technology Development Corp.
# Completed:  Mission Produce, Inc.
# Completed:  MYCOGEN CORP
# Completed:  New Ruipeng Pet Group Inc.
# Completed:  PACIFIC FARM SERVICE INC
# Completed:  Pet DRx CORP
# Completed:  PET PRACTICE INC
# Completed:  PHYTOTECH INC /NJ/
# Completed:  PIMI AGRO CLEANTECH, INC.
# Completed:  SFC MARKETING CORP
# Completed:  SoCal Harvest, Inc.
# Completed:  Stevia Corp
# Completed:  SUN DESERT INC
# Completed:  SUN HARVEST INC
# Completed:  SUN WORLD AVOCADO
# Completed:  SUN WORLD BRANDS
# Completed:  SUN WORLD EXPORT INC
# Completed:  SUN WORLD INTERNATIONAL INC /DE/
# Completed:  SUN WORLD MANAGEMENT CORP
# Completed:  SUN WORLD RAYO
# Completed:  Sustainable Green Team, Ltd.
# Completed:  USA BIOMASS CORP
# Completed:  VCA INC
# Completed:  WINESHARES INTERNATIONAL INC
# Completed:  XLNT Veterinary Care Inc
# Completed:  Zero Gravity Solutions, Inc.
# Completed:  AMERICAN SEAFOODS CORP
# Completed:  AMERICAN SEAFOODS GROUP LLC
# Completed:  AquaBounty Technologies, Inc.
# Completed:  Atlas South Sea Pearl LTD
# Completed:  HQ SUSTAINABLE MARITIME INDUSTRIES, INC.
# Completed:  Marine Harvest ASA
# Completed:  NaturalShrimp Holdings Inc
# Completed:  NaturalShrimp Inc
# Completed:  New Global Energy, Inc.
# Completed:  Northwest Trout Farms, Inc.
# Completed:  Pingtan Marine Enterprise Ltd.
# Completed:  Sino Agro Food, Inc.
# Completed:  STEELE OCEANIC CORP
# Completed:  Umami Sustainable Seafood Inc.

# %%
db_name = "SEC_Filings.db"
table_name = "Reports_Data"

engine = sqlalchemy.create_engine('sqlite:///' + db_name, execution_options={"sqlite_raw_colnames": True})
df = pd.read_sql_table(table_name, engine)
df
# Out:
#        SIC         CIK               Company Filing_Date  \
# 0     6029  0001527383   BankGuam Holding Co  2022-03-28
# 1     6029  0001527383   BankGuam Holding Co  2021-03-22
# 2     6029  0001527383   BankGuam Holding Co  2020-03-19
# 3     6029  0001527383   BankGuam Holding Co  2019-03-15
# 4     6029  0001527383   BankGuam Holding Co  2018-06-29
# ...    ...         ...                   ...         ...
# 3969  0900  0001488419  Sino Agro Food, Inc.  2021-06-23
# 3970  0900  0001488419  Sino Agro Food, Inc.  2021-02-10
# 3971  0900  0001488419  Sino Agro Food, Inc.  2019-04-15
# 3972  0900  0001488419  Sino Agro Food, Inc.  2018-04-17
# 3973  0900  0001488419  Sino Agro Food, Inc.  2017-03-16
#
#                                             Filing_Link          Accession_No
# 0     https://www.sec.gov/Archives/edgar/data/152738...  0001564590-22-011871
# 1     https://www.sec.gov/Archives/edgar/data/152738...  0001564590-21-014469
# 2     https://www.sec.gov/Archives/edgar/data/152738...  0001564590-20-011686
# 3     https://www.sec.gov/Archives/edgar/data/152738...  0001564590-19-007926
# 4     https://www.sec.gov/Archives/edgar/data/152738...  0001564590-18-016424
# ...                                                 ...                   ...
# 3969  https://www.sec.gov/Archives/edgar/data/148841...  0001104659-21-084333
# 3970  https://www.sec.gov/Archives/edgar/data/148841...  0001104659-21-016840
# 3971  https://www.sec.gov/Archives/edgar/data/148841...  0001144204-19-019679
# 3972  https://www.sec.gov/Archives/edgar/data/148841...  0001144204-18-020929
# 3973  https://www.sec.gov/Archives/edgar/data/148841...  0001144204-17-015163
#
# [3974 rows x 6 columns]

# %%
user_agent = {'User-agent' : '<evanmcgarry7@gmail.com>', 'Host': 'www.sec.gov'} ## REMOVE LATER

# Retrieve Filing Documents as HTML and Clean Data

# Function to Clean HTML
def restore_windows_1252_characters(restore_string):
    """
    Replace C1 control characters in the Unicode string s by the
    characters at the corresponding code points in Windows-1252,
    where possible.
    """
    def to_windows_1252(match):
        try:
            return bytes([ord(match.group(0))]).decode('windows-1252')
        except UnicodeDecodeError:
            # No character at the corresponding code point: remove it.
            return ''
    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# Create New DataFrame Column to Store the Normalised Text
df['Filing_Document_Text'] = ''

# Loop Through Filing Links
for i in range(0, len(df)):
    response = requests.get(df['Filing_Link'][i], headers=user_agent)
    soup = BeautifulSoup(response.content, 'lxml')
    filing_document = soup.find('body')
    filing_doc_text = filing_document.extract()
    filing_doc_string = str(filing_doc_text)
    text_bytes = bytes(filing_doc_string, 'utf-8')
    doc_soup = BeautifulSoup(text_bytes, 'html5')
    doc_text = doc_soup.html.body.get_text(' ', strip = True)
    doc_text_normalise = restore_windows_1252_characters(unicodedata.normalize('NFKD', doc_text))

    # Additional Cleaning Steps
    doc_text_normalise = doc_text_normalise.replace('Â', '').replace('  ', ' ').replace('\n', ' ')
    doc_text_normalise = doc_text_normalise.lower()

    # Store Cleaned Data in DataFrame
    df['Filing_Document_Text'][i] = [doc_text_normalise]
    print("Completed:"+str(df['Company'][i]))
# Out:
# c:\Users\Gavin\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Completed:BankGuam Holding Co
# Completed:BankGuam Holding Co
# Completed:BankGuam Holding Co
# Completed:BankGuam Holding Co
# Completed:BankGuam Holding Co
# Completed:BankGuam Holding Co
# Completed:Esquire Financial Holdings, Inc.
# Completed:Esquire Financial Holdings, Inc.
# Completed:Esquire Financial Holdings, Inc.
# Completed:Esquire Financial Holdings, Inc.
# Completed:Esquire Financial Holdings, Inc.
# Completed:Esquire Financial Holdings, Inc.
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:PEAPACK GLADSTONE FINANCIAL CORP
# Completed:SUN BANCORP INC /NJ/
# Completed:1ST SOURCE CORP
# Completed:1ST SOURCE CORP
# Completed:1ST SOURCE CORP
# Completed:1ST SOURCE CORP
# Completed:1ST SOURCE CORP
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4548\1758585731.py in <module>
#      29     filing_doc_string = str(filing_doc_text)
#      30     text_bytes = bytes(filing_doc_string, 'utf-8')
# ---> 31     doc_soup = BeautifulSoup(text_bytes, 'html5')
#      32     doc_text = doc_soup.html.body.get_text(' ', strip = True)
#      33     doc_text_normalise = restore_windows_1252_characters(unicodedata.normalize('NFKD', doc_text))
#
# c:\Users\Gavin\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# c:\Users\Gavin\anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     449         self.builder.reset()
#     450
# --> 451         self.builder.feed(self.markup)
#     452         # Close out any unfinished strings and close all the open tags.
#     453         self.endData()
#
# c:\Users\Gavin\anaconda3\lib\site-packages\bs4\builder\_html5lib.py in feed(self, markup)
#      91             else:
#      92                 extra_kwargs['encoding'] = self.user_specified_encoding
# ---> 93         doc = parser.parse(markup, **extra_kwargs)
#      94
#      95         # Set the character encoding detected by the tokenizer.
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in parse(self, stream, *args, **kwargs)
#     282
#     283         """
# --> 284         self._parse(stream, False, None, *args, **kwargs)
#     285         return self.tree.getDocument()
#     286
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in _parse(self, stream, innerHTML, container, scripting, **kwargs)
#     131
#     132         try:
# --> 133             self.mainLoop()
#     134         except _ReparseException:
#     135             self.reset()
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in mainLoop(self)
#     238                         new_token = phase.processSpaceCharacters(new_token)
#     239                     elif type == StartTagToken:
# --> 240                         new_token = phase.processStartTag(new_token)
#     241                     elif type == EndTagToken:
#     242                         new_token = phase.processEndTag(new_token)
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in processStartTag(self, token)
#     467                     # this makes the eviction policy random on Py < 3.7 and FIFO >= 3.7
#     468                     self.__startTagCache.pop(next(iter(self.__startTagCache)))
# --> 469             return func(token)
#     470
#     471         def startTagHtml(self, token):
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in startTagOther(self, token)
#    2238
#    2239         def startTagOther(self, token):
# -> 2240             return self.parser.phases["inBody"].processStartTag(token)
#    2241
#    2242         def endTagTableCell(self, token):
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in processStartTag(self, token)
#     467                     # this makes the eviction policy random on Py < 3.7 and FIFO >= 3.7
#     468                     self.__startTagCache.pop(next(iter(self.__startTagCache)))
# --> 469             return func(token)
#     470
#     471         def startTagHtml(self, token):
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in startTagFormatting(self, token)
#    1111         def startTagFormatting(self, token):
#    1112             self.tree.reconstructActiveFormattingElements()
# -> 1113             self.addFormattingElement(token)
#    1114
#    1115         def startTagNobr(self, token):
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\html5parser.py in addFormattingElement(self, token)
#     956         # helper
#     957         def addFormattingElement(self, token):
# --> 958             self.tree.insertElement(token)
#     959             element = self.tree.openElements[-1]
#     960
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\treebuilders\base.py in insertElementNormal(self, token)
#     325         assert isinstance(name, text_type), "Element %s not unicode" % name
#     326         namespace = token.get("namespace", self.defaultNamespace)
# --> 327         element = self.elementClass(name, namespace)
#     328         element.attributes = token["data"]
#     329         self.openElements[-1].appendChild(element)
#
# c:\Users\Gavin\anaconda3\lib\site-packages\bs4\builder\_html5lib.py in elementClass(self, name, namespace)
#     162             # tag. We don't know when the tag started, but we do know
#     163             # where it ended -- the character just before this one.
# --> 164             sourceline, sourcepos = self.parser.tokenizer.stream.position()
#     165             kwargs['sourceline'] = sourceline
#     166             kwargs['sourcepos'] = sourcepos-1
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\_inputstream.py in position(self)
#     229     def position(self):
#     230         """Returns (line, col) of the current position in the stream."""
# --> 231         line, col = self._position(self.chunkOffset)
#     232         return (line + 1, col)
#     233
#
# c:\Users\Gavin\anaconda3\lib\site-packages\html5lib\_inputstream.py in _position(self, offset)
#     222         lastLinePos = chunk.rfind('\n', 0, offset)
#     223         if lastLinePos == -1:
# --> 224             positionColumn = self.prevNumCols + offset
#     225         else:
#     226             positionColumn = offset - (lastLinePos + 1)
#
# KeyboardInterrupt:

# %%
# Convert 10-K Data to String
df['Filing_Document_Text'] = df['Filing_Document_Text'].astype(str)

# Insert into SQLite Database
# Create SQLite Table
db_name2 = "SEC_Filings.db"
table_name2 = "10K_Data"

engine2 = sqlalchemy.create_engine('sqlite:///' + db_name, execution_options={"sqlite_raw_colnames": True})
df.to_sql(table_name2, engine2, if_exists='replace', index=False)
# Out:
# 3917
